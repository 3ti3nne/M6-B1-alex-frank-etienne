# %% [markdown]
# # M6-B1 — Analyse de dérive (à compléter)

# %%
# Imports communs
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from scipy.stats import ks_2samp, chi2_contingency

print(os.getcwd())
# Out:
# /Users/franckcwalter/Code/formations/simplon_ia/022_M6_b1/M6-B1-alex-frank-etienne/notebooks

# %% [markdown]
# ## 1. Exploration — distributions référence vs prod

# %% [markdown]
# ### Distributions des variables numériques
#
# Comparaison avec les mêmes classes et une densité pour tenir compte des tailles différentes des deux jeux.

# %%
ROOT = next(p for p in (Path.cwd(), *Path.cwd().parents)
            if (p / "data" / "reference_set.csv").exists())
reference = pd.read_csv(ROOT / "data/reference_set.csv")
prod = pd.read_csv(ROOT / "data/prod_3months.csv")
features = reference.drop(columns=["loan_status"])

numeriques = features.select_dtypes(include="number").columns.tolist()
display(pd.concat({"Référence": reference[numeriques].describe().T,
                   "Production": prod[numeriques].describe().T}, axis=1).round(2))

fig, axes = plt.subplots((len(numeriques) + 2) // 3, 3, figsize=(15, 11), squeeze=False)
for ax, col in zip(axes.flat, numeriques):
    bornes = np.histogram_bin_edges(pd.concat([reference[col], prod[col]]).dropna(), bins=25)
    ax.hist(reference[col].dropna(), bins=bornes, density=True, alpha=0.5, label="Référence")
    ax.hist(prod[col].dropna(), bins=bornes, density=True, alpha=0.5, label="Production")
    ax.set_title(col)
    ax.set_ylabel("Densité")
    ax.legend()
for ax in list(axes.flat)[len(numeriques):]:
    ax.set_visible(False)
fig.tight_layout()
plt.show()
# Out:
#                Référence                                                    \
#                    count      mean       std       min       25%       50%
# loan_amnt         1500.0  13828.40   7761.01   1900.00   8300.00  11900.00
# int_rate          1500.0     12.61      4.47      5.04      9.56     12.01
# installment       1500.0    417.86    246.17     44.61    238.46    354.45
# annual_inc        1500.0  76938.40  45641.44  12000.00  44275.00  65950.00
# dti               1500.0     17.56      8.05      1.21     11.52     16.48
# delinq_2yrs       1500.0      0.31      0.56      0.00      0.00      0.00
# fico_range_low    1500.0    707.37     26.37    631.00    690.00    707.00
# revol_util        1480.0     50.57     20.01      3.20     35.60     50.90
#
#                                     Production                                \
#                      75%        max      count      mean       std       min
# ...

# %% [markdown]
# ### Distributions des variables catégorielles
#
# Proportions en pourcentage de chaque population ; les valeurs manquantes sont une catégorie séparée.

# %%
ROOT = next(p for p in (Path.cwd(), *Path.cwd().parents)
            if (p / "data" / "reference_set.csv").exists())
reference = pd.read_csv(ROOT / "data/reference_set.csv")
prod = pd.read_csv(ROOT / "data/prod_3months.csv")
features = reference.drop(columns=["loan_status"])

categorielles = features.select_dtypes(exclude="number").columns.tolist()
fig, axes = plt.subplots((len(categorielles) + 1) // 2, 2, figsize=(15, 15), squeeze=False)
for ax, col in zip(axes.flat, categorielles):
    proportions = pd.DataFrame({
        "Référence": reference[col].fillna("(manquant)").value_counts(normalize=True),
        "Production": prod[col].fillna("(manquant)").value_counts(normalize=True)
    }).fillna(0).mul(100).sort_index()
    display(proportions.round(2).rename_axis(col))
    proportions.plot.bar(ax=ax)
    ax.set_title(col)
    ax.set_ylabel("Part des dossiers (%)")
    ax.tick_params(axis="x", rotation=45)
for ax in list(axes.flat)[len(categorielles):]:
    ax.set_visible(False)
fig.tight_layout()
plt.show()
# Out:
#            Référence  Production
# term
# 36 months      70.53        72.0
# 60 months      29.47        28.0
#        Référence  Production
# grade
# A          18.33       15.03
# B          30.33       25.57
# C          27.40       27.30
# D          13.87       17.90
# E           7.27        9.40
# F           1.60        3.30
# G           1.20        1.50
#             Référence  Production
# emp_length
# (manquant)       3.33        3.80
# 1 year           7.13        6.87
# 10+ years       37.20       33.77
# 2 years          7.87        8.73
# 3 years          7.13        7.47
# 4 years          7.20        7.03
# 5 years          6.67        6.43
# 6 years          3.93        4.83
# 7 years          5.53        5.40
# 8 years          5.00        4.83
# 9 years          3.93        4.60
# < 1 year         5.07        6.23
#                 Référence  Production
# home_ownership
# MORTGAGE            49.40       49.40
# OTHER                0.80        1.20
# ...

# %% [markdown]
# ### Conclusions de l’exploration visuelle
#
# - **`int_rate` (taux d’intérêt du prêt)** : la distribution en production est décalée vers la droite. Les taux d’intérêt sont globalement plus élevés que dans la référence.
# - **`revol_util` (part du crédit renouvelable disponible déjà utilisée)** : la distribution est également décalée vers la droite. Les clients utilisent une part plus importante de leur crédit disponible. Par exemple, 3 000 € utilisés sur une limite de 5 000 € correspondent à 60 %.
# - **`grade` (catégorie de risque du prêt, de A à G)** : la répartition change, avec moins de dossiers A/B et davantage de dossiers D/E/F en production. La part de C reste proche de celle de la référence.
# - **`annual_inc` (revenu annuel)** : le changement est moins visible, mais les revenus semblent globalement plus faibles en production.
#
# - **Les autres variables numériques** présentent des distributions visuellement assez proches entre référence et production.
# - **Les autres variables catégorielles** (`term`, `emp_length`, `home_ownership`, `verification_status`, `purpose`) présentent des proportions visuellement assez proches entre référence et production.

# %% [markdown]
# ## 2. Détection statistique — PSI · KS · Chi²

# %%
reference = pd.read_csv("../data/reference_set.csv")
prod = pd.read_csv("../data/prod_3months.csv")


def psi(ref, cur, n_bins=10, eps=1e-6):
    ref = ref.dropna()
    cur = cur.dropna()

    edges = np.unique(np.quantile(ref, np.linspace(0, 1, n_bins + 1)))
    edges[0], edges[-1] = -np.inf, np.inf

    p_ref = np.histogram(ref, edges)[0] / len(ref)
    p_cur = np.histogram(cur, edges)[0] / len(cur)

    p_ref, p_cur = p_ref + eps, p_cur + eps
    p_ref, p_cur = p_ref / p_ref.sum(), p_cur / p_cur.sum()

    return float(np.sum((p_cur - p_ref) * np.log(p_cur / p_ref)))


for column in ["int_rate", "loan_amnt"]:
    ref = reference[column]
    cur = prod[column]

    print(column)
    print("PSI :", round(psi(ref, cur), 3))
    print("KS p-value :", ks_2samp(ref.dropna(), cur.dropna()).pvalue)
    print()

grades = sorted(
    set(reference["grade"].dropna().unique())
    | set(prod["grade"].dropna().unique())
)

ref_counts = reference["grade"].value_counts().reindex(grades, fill_value=0)
prod_counts = prod["grade"].value_counts().reindex(grades, fill_value=0)

table = pd.DataFrame({
    "reference": ref_counts,
    "prod": prod_counts
})

print(table)

chi2, p_value, dof, expected = chi2_contingency(table.T)

print("Chi² :", chi2)
print("p-value :", p_value)

print("Grades normalized %")
grade_compare = pd.DataFrame({
    "reference": reference["grade"].value_counts(normalize=True),
    "prod": prod["grade"].value_counts(normalize=True)
}) * 100

grade_compare = grade_compare.round(2)

print(grade_compare)
# Out:
# int_rate
# PSI : 0.444
# KS p-value : 4.627646432732096e-65
#
# loan_amnt
# PSI : 0.003
# KS p-value : 0.9890912120116152
#
#        reference  prod
# grade
# A            275   451
# B            455   767
# C            411   819
# D            208   537
# E            109   282
# F             24    99
# G             18    45
# Chi² : 41.40073384679395
# p-value : 2.414183658745721e-07
# Grades normalized %
#        reference   prod
# grade
# A          18.33  15.03
# B          30.33  25.57
# C          27.40  27.30
# D          13.87  17.90
# E           7.27   9.40
# F           1.60   3.30
# G           1.20   1.50

# %%
import sys
sys.path.insert(0, str(ROOT / "src"))
from drift_detection import drift_report

rapport = drift_report(reference, prod, numeriques, categorielles)
display(rapport)
# Out:
#                 feature          type       psi     ks_pvalue   chi2_pvalue  \
# 0              int_rate     numérique  0.443619  4.627646e-65           NaN
# 1            revol_util     numérique  0.186596  3.818392e-20           NaN
# 2            annual_inc     numérique  0.066639  2.282912e-09           NaN
# 3           installment     numérique  0.014692  6.625669e-01           NaN
# 4                   dti     numérique  0.011406  1.104190e-01           NaN
# 5        fico_range_low     numérique  0.006804  4.892778e-01           NaN
# 6             loan_amnt     numérique  0.003454  9.890912e-01           NaN
# 7           delinq_2yrs     numérique  0.001762  8.878996e-01           NaN
# 8                 grade  catégorielle       NaN           NaN  3.650607e-07
# 9               purpose  catégorielle       NaN           NaN  1.992677e-01
# 10                 term  catégorielle       NaN           NaN  3.164360e-01
# ...

# %% [markdown]
# ## 3. Calibration en exploitation

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

ROOT = next(p for p in (Path.cwd(), *Path.cwd().parents)
            if (p / "data" / "predictions_log.csv").exists())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from src.calibration import reliability_table, expected_calibration_error

logs_calibration = pd.read_csv(ROOT / "data/predictions_log.csv", parse_dates=["timestamp"])
if logs_calibration["timestamp"].isna().any():
    raise ValueError("Les logs contiennent des dates manquantes.")
origine = logs_calibration["timestamp"].min().normalize()
logs_calibration["semaine"] = ((logs_calibration["timestamp"] - origine).dt.days // 7) + 1
N_BINS = 10
periodes_calibration = {"Semaines 1–4": (1, 4), "Semaines 9–12": (9, 12)}
tables_calibration = {}
resume_calibration = []
for nom, (debut, fin) in periodes_calibration.items():
    periode = logs_calibration.loc[logs_calibration["semaine"].between(debut, fin)]
    disponibles = periode.dropna(subset=["proba_default", "true_label"])
    table = reliability_table(periode["proba_default"], periode["true_label"], N_BINS)
    tables_calibration[nom] = table
    resume_calibration.append({
        "Période": nom,
        "Début inclus": (origine + pd.Timedelta(weeks=debut - 1)).date(),
        "Fin exclue": (origine + pd.Timedelta(weeks=fin)).date(),
        "Dossiers": len(periode), "Dossiers évalués": len(disponibles),
        "Dossiers exclus": len(periode) - len(disponibles),
        "Risque prédit moyen (%)": disponibles["proba_default"].mean() * 100,
        "Défauts observés (%)": disponibles["true_label"].mean() * 100,
        "ECE (points de %)": expected_calibration_error(
            periode["proba_default"], periode["true_label"], N_BINS) * 100,
    })
resume_calibration = pd.DataFrame(resume_calibration).set_index("Période")
display(resume_calibration.round(2))
print("Couverture des logs :", logs_calibration["timestamp"].min(), "à", logs_calibration["timestamp"].max())
print("Dossiers hors des deux fenêtres :",
      len(logs_calibration) - int(resume_calibration["Dossiers"].sum()))
# Out:
#               Début inclus  Fin exclue  Dossiers  Dossiers évalués  \
# Période
# Semaines 1–4    2026-03-02  2026-03-30      1003              1003
# Semaines 9–12   2026-04-27  2026-05-25       997               997
#
#                Dossiers exclus  Risque prédit moyen (%)  Défauts observés (%)  \
# Période
# Semaines 1–4                 0                    44.27                 20.24
# Semaines 9–12                0                    51.58                 20.06
#
#                ECE (points de %)
# Période
# Semaines 1–4               24.03
# Semaines 9–12              31.52
# Couverture des logs : 2026-03-02 00:00:00 à 2026-05-24 23:00:00
# Dossiers hors des deux fenêtres : 1000

# %% [markdown]
# ### Lecture du tableau
#
# - **Périodes et dossiers** : on compare les semaines 1–4 (1 003 dossiers) aux semaines 9–12 (997 dossiers). Tous ces dossiers sont évalués ; aucun n’est exclu pour probabilité ou label manquant. La date de fin indiquée est exclue de la fenêtre.
# - **Risque prédit moyen (%)** : moyenne des probabilités de défaut annoncées par le modèle, soit **44,27 %** au début et **51,58 %** à la fin.
# - **Défauts observés (%)** : proportion de dossiers ayant réellement fait défaut, soit **20,24 %** au début et **20,06 %** à la fin.
# - **ECE (points de %)** : pour chacune des 10 tranches de probabilités, on calcule l’écart absolu entre risque moyen annoncé et taux de défaut observé, puis on fait la moyenne de ces écarts pondérée par le nombre de dossiers. L’ECE vaut **24,03 points** au début et **31,52 points** à la fin. **Plus il est proche de zéro, meilleur est l’accord**, pour ce découpage. En l'espèce, il s'éloigne de zéro donc la calibration se dégrade.

# %% [markdown]
# ### Diagramme de calibration

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot([0, 1], [0, 1], "k--", label="Calibration parfaite")
for nom, table in tables_calibration.items():
    ax.plot(table["confiance_moyenne"], table["taux_observe"], "o-", label=nom)
ax.set(xlabel="Probabilité moyenne de défaut prédite",
       ylabel="Fréquence de défaut observée", xlim=(0, 1), ylim=(0, 1),
       title="Calibration : début et fin de période")
ax.legend()
ax.grid(alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Lecture du graphique
#
# Les deux courbes sont sous la diagonale : **le modèle annonce des risques de défaut plus élevés que les taux réellement observés**, au début comme à la fin de la période.
#
# La courbe orange est généralement plus basse que la bleue à probabilités annoncées comparables. Par exemple, pour un risque annoncé proche de **55 %**, on observe environ **28 % de défauts au début**, contre **21 % à la fin** : la surestimation est plus importante en fin de période dans cette tranche.
#
# Ce décalage n’est pas identique partout : autour de **65 % de risque annoncé**, les deux courbes se rejoignent presque, avec environ **34 % de défauts observés**.

# %% [markdown]
# ### Interprétation — la confiance a-t-elle dérivé ?
#
# **Oui, la calibration se dégrade entre les semaines 1–4 et 9–12, dans le sens d’une sur-confiance : le modèle surestime le risque de défaut.** Les deux courbes sont sous la diagonale ; la courbe de fin de période est généralement plus basse à probabilités prédites comparables.
#
# Au début, le risque prédit moyen est de **44,27 %**, contre **20,24 %** de défauts observés. À la fin, il atteint **51,58 %**, alors que les défauts observés restent à **20,06 %** : la surestimation moyenne s’accentue.
#
# L’ECE passe de **24,03 à 31,52 points de pourcentage**, soit **+7,49 points**, avec le même découpage en classes. Les probabilités annoncées sont donc moins bien calibrées en fin de période.

# %% [markdown]
# ## 4. Performance dans le temps

# %%
from sklearn.metrics import roc_auc_score, f1_score

perf_logs = logs_calibration

weekly = perf_logs.groupby("semaine").apply(lambda g: pd.Series({
    "n": len(g),
    "f1_macro": f1_score(g["true_label"], g["prediction"], average="macro"),
    "auc": roc_auc_score(g["true_label"], g["proba_default"]),
    "predicted_default_%": g["prediction"].mean() * 100,
    "actual_default_%": g["true_label"].mean() * 100,
}), include_groups=False)
weekly.index.name = "week"
display(weekly.round(3))

early = perf_logs[perf_logs["semaine"] <= 4]
late = perf_logs[perf_logs["semaine"] >= 9]
auc_early = roc_auc_score(early["true_label"], early["proba_default"])
auc_late = roc_auc_score(late["true_label"], late["proba_default"])
f1_early = f1_score(early["true_label"], early["prediction"], average="macro")
f1_late = f1_score(late["true_label"], late["prediction"], average="macro")
print(f"AUC      : {auc_early:.3f} -> {auc_late:.3f}  (delta = {auc_late - auc_early:+.3f})")
print(f"Macro F1 : {f1_early:.3f} -> {f1_late:.3f}  (delta = {f1_late - f1_early:+.3f})")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(weekly.index, weekly["f1_macro"], "o-", label="Macro F1")
axes[0].plot(weekly.index, weekly["auc"], "o-", label="AUC")
axes[0].set(xlabel="Week", ylim=(0, 1), title="Performance by week")
axes[0].legend()
axes[0].grid(alpha=0.3)
axes[1].plot(weekly.index, weekly["predicted_default_%"], "o-", label="Predicted defaults (%)")
axes[1].plot(weekly.index, weekly["actual_default_%"], "o-", label="Actual defaults (%)")
axes[1].set(xlabel="Week", ylim=(0, 100), title="Predicted vs actual default rate")
axes[1].legend()
axes[1].grid(alpha=0.3)
fig.tight_layout()
plt.show()
# Out:
#           n  f1_macro    auc  predicted_default_%  actual_default_%
# week
# 1     226.0     0.611  0.716               38.938            21.239
# 2     293.0     0.622  0.777               37.201            16.382
# 3     236.0     0.603  0.738               47.034            24.153
# 4     248.0     0.591  0.721               44.758            20.161
# 5     234.0     0.575  0.740               42.735            16.667
# 6     269.0     0.553  0.727               45.725            18.587
# 7     254.0     0.556  0.717               43.307            16.929
# 8     243.0     0.572  0.759               48.560            16.049
# 9     233.0     0.607  0.798               51.931            21.459
# 10    248.0     0.518  0.757               55.645            16.129
# 11    241.0     0.559  0.732               56.846            22.822
# 12    275.0     0.522  0.708               61.818            20.000
# AUC      : 0.742 -> 0.746  (delta = +0.004)
# ...

# %% [markdown]
# ### Temporality PSI by 2-week window

# %%
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))
from drift_detection import population_stability_index, PSI_STABLE, PSI_DRIFT

TOP_FEATURES = ["int_rate", "revol_util", "annual_inc"]

prod_ts = prod.assign(timestamp=pd.to_datetime(prod["timestamp"]))
start = prod_ts["timestamp"].min().normalize()
prod_ts["window"] = (prod_ts["timestamp"] - start).dt.days // 14 + 1

rows = []
for window, chunk in prod_ts.groupby("window"):
    row = {
        "window": window,
        "from": (start + pd.Timedelta(weeks=2 * (window - 1))).date(),
        "to": (start + pd.Timedelta(weeks=2 * window, days=-1)).date(),
        "n": len(chunk),
    }
    for col in TOP_FEATURES:
        row[col] = population_stability_index(reference[col], chunk[col])
    rows.append(row)
psi_by_window = pd.DataFrame(rows).set_index("window")
display(psi_by_window.round(3))

fig, ax = plt.subplots(figsize=(9, 4))
for col in TOP_FEATURES:
    ax.plot(psi_by_window.index, psi_by_window[col], "o-", label=col)
ax.axhline(PSI_STABLE, color="grey", linestyle=":", label=f"{PSI_STABLE} (investigate)")
ax.axhline(PSI_DRIFT, color="red", linestyle="--", label=f"{PSI_DRIFT} (strong signal)")
ax.set_xticks(psi_by_window.index)
ax.set_xticklabels([f"W{2 * w - 1}-{2 * w}" for w in psi_by_window.index])
ax.set(xlabel="2-week window", ylabel="PSI vs reference", title="PSI by 2-week window")
ax.legend()
ax.grid(alpha=0.3)
fig.tight_layout()
plt.show()
# Out:
#               from          to    n  int_rate  revol_util  annual_inc
# window
# 1       2026-03-02  2026-03-15  519     0.018       0.026       0.024
# 2       2026-03-16  2026-03-29  484     0.379       0.061       0.040
# 3       2026-03-30  2026-04-12  503     1.397       0.087       0.045
# 4       2026-04-13  2026-04-26  497     1.628       0.377       0.082
# 5       2026-04-27  2026-05-10  481     2.924       0.666       0.171
# 6       2026-05-11  2026-05-24  516     3.601       0.806       0.229

# %% [markdown]
# ## 5. Diagnostic & recommandation

# %%
import sys
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))
from recommendations import DriftDiagnosis, diagnose_drift_type, recommend

n_features_drift = int((rapport["verdict"] == "dérive").sum())
auc_stable = abs(auc_late - auc_early) < 0.03

ece_debut = resume_calibration.loc["Semaines 1–4", "ECE (points de %)"]
ece_fin = resume_calibration.loc["Semaines 9–12", "ECE (points de %)"]
calibration_degraded = (ece_fin - ece_debut) > 2.0

f1_drop = f1_early - f1_late

diagnostic = DriftDiagnosis(
    n_features_drift=n_features_drift,
    auc_stable=auc_stable,
    calibration_degraded=calibration_degraded,
    f1_drop=f1_drop,
)
drift_type = diagnose_drift_type(diagnostic)
recommandation = recommend(diagnostic)

print(f"Features en dérive (PSI > {PSI_DRIFT})     : {n_features_drift} —",
      ", ".join(rapport.loc[rapport['verdict'] == 'dérive', 'feature']))
print(f"AUC stable                        : {auc_stable} (delta = {auc_late - auc_early:+.3f})")
print(f"Calibration dégradée              : {calibration_degraded} (ECE {ece_debut:.2f} -> {ece_fin:.2f} points)")
print(f"F1 macro                          : {f1_early:.3f} -> {f1_late:.3f} (baisse = {f1_drop:.3f})")
print()
print("Type de dérive retenu :", drift_type)
print()
for cle, valeur in recommandation.items():
    print(f"{cle:<14}: {valeur}")
# Out:
# Features en dérive (PSI > 0.25)     : 2 — int_rate, grade
# AUC stable                        : True (delta = +0.004)
# Calibration dégradée              : True (ECE 24.03 -> 31.52 points)
# F1 macro                          : 0.609 -> 0.551 (baisse = 0.058)
#
# Type de dérive retenu : data drift
#
# action        : réentraîner sur données récentes
# justification : Les pourcentages de risque annoncés ne sont plus fiables.
# urgence       : moyenne
# drift_type    : data drift
